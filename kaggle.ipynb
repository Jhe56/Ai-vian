# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rohanrao/xeno-canto-bird-recordings-extended-a-m")

print("Path to dataset files:", path)
# Out:
# Resuming download from 52428800 bytes (18113703935 bytes left)...
# Resuming download to C:\Users\joano\.cache\kagglehub\datasets\rohanrao\xeno-canto-bird-recordings-extended-a-m\11.archive (52428800/18166132735) bytes left.
# 100%|██████████| 16.9G/16.9G [42:28<00:00, 7.11MB/s]
# Extracting files...
# Path to dataset files: C:\Users\joano\.cache\kagglehub\datasets\rohanrao\xeno-canto-bird-recordings-extended-a-m\versions\11

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
